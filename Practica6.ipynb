# %%
ContenedorPseudoAleatorios = []

semilla1 = 2334
semilla2 = 3423

result = semilla1 * semilla2
 
for i in range(1000):
    cadenaString = str(result)
    while True:
        largo = len(cadenaString)
        largoEntero = int(largo)
        if largoEntero == 8:
            Xi = cadenaString[2:6]
            ri = Xi
            ri = '0.' + ri
            ContenedorPseudoAleatorios.append(ri)
            break
        elif largoEntero == 4:
            cadenaString = '0000' + cadenaString
        elif largoEntero == 5:
            cadenaString = '000' + cadenaString
        elif largoEntero == 6:
            cadenaString = '00' + cadenaString
        elif largoEntero == 7:
            cadenaString = '0' + cadenaString
        elif largoEntero == 9:
            cadenaString = cadenaString[0:8]
        elif largoEntero == 10:
            cadenaString = cadenaString[0:9]

    XiEntero = int(Xi)

    result = semilla2 * XiEntero
    semilla2 = XiEntero



print('---')

print('\n'.join(map(str, ContenedorPseudoAleatorios)))
print('*-*-*-*')
for i in range(998):
    if ContenedorPseudoAleatorios[i] == ContenedorPseudoAleatorios[i+1]:
        print(ContenedorPseudoAleatorios[i])
# Out:
# ---
# 0.9892
# 0.8603
# 0.1008
# 0.6718
# 0.7717
# 0.8428
# 0.0388
# 0.2700
# 0.0476
# 0.2852
# 0.3575
# 0.1959
# 0.0034
# 0.0666
# 0.0226
# 0.1505
# 0.3401
# 0.1185
# 0.0301
# 0.3566
# 0.0733
# 0.6138
# 0.4991
# 0.6347
# 0.6778
# 0.0199
# 0.3488
# 0.6941
# 0.2102
# 0.5899
# 0.3996
# 0.5724
# 0.8731
# 0.9762
# 0.2320
# 0.6478
# 0.0289
# 0.8721
# 0.5203
# 0.3753
# 0.5268
# 0.7708
# 0.6057
# 0.6873
# 0.6297
# 0.2792
# 0.5812
# 0.2271
# 0.1990
# 0.5192
# 0.3320
# 0.2374
# 0.8816
# 0.9291
# 0.9094
# 0.4923
# 0.7697
# 0.8923
# 0.6803
# 0.7031
# 0.8318
# 0.4838
# 0.2424
# 0.7273
# 0.6297
# 0.7980
# 0.2500
# 0.9500
# 0.7500
# 0.2500
# 0.7500
# 0.7500
# 0.2500
# 0.7500
# 0.7500
# 0.2500
# 0.7500
# 0.7500
# 0.2500
# 0.7500
# 0.7500
# 0.2500
# 0.7500
# 0.7500
# 0.2500
# 0.7500
# 0.7500
# 0.2500
# 0.7500
# 0.7500
# 0.2500
# 0.7500
# 0.7500
# 0.2500
# 0.7500
# 0.7500
# 0.2500
# 0.7500
# 0.7500
# 0.2500
# 0.7500
# 0.7500
# 0.2500
# 0.7500
# 0.7500
# 0.2500
# 0.7500
# 0.7500
# 0.2500
# 0.7500
# ...
